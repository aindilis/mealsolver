# %% [markdown]
# # Food item lookup in the USDA SR dataset
#
# This notebook contains experiments with food item lookups against the USDA SR dataset.
#
# The dataset can be downloaded from the USDA FoodDataCentral site: https://fdc.nal.usda.gov/download-datasets.html

# %%
import pandas as pd

# for regex matching
import re

# for fuzzy string matching
from fuzzywuzzy import fuzz, process

# %% [markdown]
# Food item descriptions are contained in the `FOOD_DES` table (https://www.ars.usda.gov/ARSUserFiles/80400525/Data/SR-Legacy/SR-Legacy_Doc.pdf Section 4.1). This contains fields holding various names / descriptions that can be searched against.

# %%
FOOD_DES_filepath = "USDA_SR/FOOD_DES.txt"

FOOD_DES_schema = [
    "NDB_No",
    "FdGrp_Cd",
    "Long_Desc",
    "Shrt_Desc",
    "ComName",
    "ManufacName",
    "Survey",
    "Ref_desc",
    "Refuse",
    "SciName",
    "N_Factor",
    "Pro_Factor",
    "Fat_Factor",
    "CHO_Factor"
]

SR_foods = pd.read_csv(
        FOOD_DES_filepath,
        delimiter = "^",
        quotechar = "~",
        names=FOOD_DES_schema
    )
SR_foods[0:20]
# Out:
#     NDB_No  FdGrp_Cd                                          Long_Desc  \
# 0     1001       100                                     Butter, salted
# 1     1002       100                         Butter, whipped, with salt
# 2     1003       100                              Butter oil, anhydrous
# 3     1004       100                                       Cheese, blue
# 4     1005       100                                      Cheese, brick
# 5     1006       100                                       Cheese, brie
# 6     1007       100                                  Cheese, camembert
# 7     1008       100                                    Cheese, caraway
# 8     1009       100  Cheese, cheddar (Includes foods for USDA's Foo...
# 9     1010       100                                   Cheese, cheshire
# 10    1011       100                                      Cheese, colby
# 11    1012       100      Cheese, cottage, creamed, large or small curd
# 12    1013       100               Cheese, cottage, creamed, with fruit
# 13    1014       100  Cheese, cottage, nonfat, uncreamed, dry, large...
# 14    1015       100                Cheese, cottage, lowfat, 2% milkfat
# 15    1016       100                Cheese, cottage, lowfat, 1% milkfat
# 16    1017       100                                      Cheese, cream
# 17    1018       100                                       Cheese, edam
# 18    1019       100                                       Cheese, feta
# 19    1020       100                                    Cheese, fontina
#
#                                            Shrt_Desc ComName ManufacName  \
# 0                                   BUTTER,WITH SALT     NaN         NaN
# 1                             BUTTER,WHIPPED,W/ SALT     NaN         NaN
# 2                               BUTTER OIL,ANHYDROUS     NaN         NaN
# 3                                        CHEESE,BLUE     NaN         NaN
# 4                                       CHEESE,BRICK     NaN         NaN
# 5                                        CHEESE,BRIE     NaN         NaN
# 6                                   CHEESE,CAMEMBERT     NaN         NaN
# 7                                     CHEESE,CARAWAY     NaN         NaN
# 8                                     CHEESE,CHEDDAR     NaN         NaN
# 9                                    CHEESE,CHESHIRE     NaN         NaN
# 10                                      CHEESE,COLBY     NaN         NaN
# 11               CHEESE,COTTAGE,CRMD,LRG OR SML CURD     NaN         NaN
# 12                       CHEESE,COTTAGE,CRMD,W/FRUIT     NaN         NaN
# 13  CHEESE,COTTAGE,NONFAT,UNCRMD,DRY,LRG OR SML CURD     NaN         NaN
# 14                  CHEESE,COTTAGE,LOWFAT,2% MILKFAT     NaN         NaN
# 15                  CHEESE,COTTAGE,LOWFAT,1% MILKFAT     NaN         NaN
# 16                                      CHEESE,CREAM     NaN         NaN
# 17                                       CHEESE,EDAM     NaN         NaN
# 18                                       CHEESE,FETA     NaN         NaN
# 19                                    CHEESE,FONTINA     NaN         NaN
#
#    Survey Ref_desc  Refuse SciName  N_Factor  Pro_Factor  Fat_Factor  \
# 0       Y      NaN     0.0     NaN      6.38        4.27        8.79
# 1       Y      NaN     0.0     NaN      6.38         NaN         NaN
# 2       Y      NaN     0.0     NaN      6.38        4.27        8.79
# 3       Y      NaN     0.0     NaN      6.38        4.27        8.79
# 4       Y      NaN     0.0     NaN      6.38        4.27        8.79
# 5       Y      NaN     0.0     NaN      6.38        4.27        8.79
# 6       Y      NaN     0.0     NaN      6.38        4.27        8.79
# 7     NaN      NaN     0.0     NaN      6.38        4.27        8.79
# 8       Y      NaN     0.0     NaN       NaN         NaN         NaN
# 9     NaN      NaN     0.0     NaN      6.38        4.27        8.79
# 10      Y      NaN     0.0     NaN      6.38        4.27        8.79
# 11      Y      NaN     0.0     NaN      6.38        4.27        8.79
# 12      Y      NaN     0.0     NaN      6.38        4.27        8.79
# 13      Y      NaN     0.0     NaN      6.38        4.27        8.79
# 14      Y      NaN     0.0     NaN      6.38         NaN         NaN
# 15      Y      NaN     0.0     NaN      6.38        4.27        8.79
# 16      Y      NaN     0.0     NaN      6.38        4.27        8.79
# 17      Y      NaN     0.0     NaN      6.38        4.27        8.79
# 18      Y      NaN     0.0     NaN      6.38        4.27        8.79
# 19      Y      NaN     0.0     NaN      6.38        4.27        8.79
#
#     CHO_Factor
# 0         3.87
# 1          NaN
# 2         3.87
# 3         3.87
# 4         3.87
# 5         3.87
# 6         3.87
# 7         3.87
# 8          NaN
# 9         3.87
# 10        3.87
# 11        3.87
# 12        3.87
# 13        3.87
# 14         NaN
# 15        3.87
# 16        3.87
# 17        3.87
# 18        3.87
# 19        3.87

# %% [markdown]
# We can see here that candidate fields for searching against include:
# * `Long_Desc`
# * `Short_Desc`
# * `ComName`
# * `ManufacName`
# * `SciName`
#
# Let's focus first on matching against the `Long_Desc` field. The most basic search method would be to simply query for names that contain the search term exactly (but ignoring case):

# %%
SR_foods[SR_foods['Long_Desc'].str.contains('apple', case=False)][0:20]
# Out:
#      NDB_No  FdGrp_Cd                                          Long_Desc  \
# 249    1304       100          Yogurt, Greek, 2% fat, pineapple, CHOBANI
# 344    3022       300  Babyfood, GERBER, 2nd Foods, apple, carrot and...
# 345    3023       300  Babyfood, finger snacks, GERBER, GRADUATES, PU...
# 347    3025       300  Babyfood, GERBER, 3rd Foods, apple, mango and ...
# 394    3115       300                   Babyfood, apples, dices, toddler
# 395    3116       300              Babyfood, fruit, applesauce, strained
# 396    3117       300                Babyfood, fruit, applesauce, junior
# 416    3142       300  Babyfood, fruit, applesauce and apricots, stra...
# 417    3143       300   Babyfood, fruit, applesauce and apricots, junior
# 418    3144       300  Babyfood, fruit, applesauce and cherries, stra...
# 419    3145       300   Babyfood, fruit, applesauce and cherries, junior
# 420    3147       300    Babyfood, fruit, applesauce with banana, junior
# 421    3150       300  Babyfood, fruit, applesauce and pineapple, str...
# 422    3151       300  Babyfood, fruit, applesauce and pineapple, junior
# 423    3152       300     Babyfood, fruit, apple and raspberry, strained
# 424    3153       300       Babyfood, fruit, apple and raspberry, junior
# 425    3154       300  Babyfood, fruit and vegetable, apple and sweet...
# 426    3156       300  Babyfood, fruit, bananas and pineapple with ta...
# 427    3157       300  Babyfood, fruit, bananas and pineapple with ta...
# 428    3158       300     Babyfood, fruit, pears and pineapple, strained
#
#                                              Shrt_Desc ComName ManufacName  \
# 249                 YOGURT,GREEK,2% FAT,PNAPPL,CHOBANI     NaN     Chobani
# 344  BABYFOOD,GERBER,2ND FOODS,APPL,CARROT & SQUASH...     NaN         NaN
# 345  BABYFOOD,FINGER SNACKS,GERBER,GRADUATES,PUFFS,...     NaN      GERBER
# 347        BABYFOOD,GERBER,3RD FOODS,APPL,MANGO & KIWI     NaN      GERBER
# 394                          BABYFOOD,APPLS,DICES,TODD     NaN         NaN
# 395                        BABYFOOD,FRUIT,APPLSAUC,STR     NaN         NaN
# 396                         BABYFOOD,FRUIT,APPLSAUC,JR     NaN         NaN
# 416               BABYFOOD,FRUIT,APPLSAUC&APRICOTS,STR     NaN         NaN
# 417                BABYFOOD,FRUIT,APPLSAUC&APRICOTS,JR     NaN         NaN
# 418               BABYFOOD,FRUIT,APPLSAUC&CHERRIES,STR     NaN         NaN
# 419              BABYFOOD,FRUIT,APPLSAUC & CHERRIES,JR     NaN         NaN
# 420                BABYFOOD,FRUIT,APPLSAUC W/BANANA,JR     NaN         NaN
# 421                 BABYFOOD,FRUIT,APPLSAUC&PNAPPL,STR     NaN         NaN
# 422                  BABYFOOD,FRUIT,APPLSAUC&PNAPPL,JR     NaN         NaN
# 423                BABYFOOD,FRUIT,APPL & RASPBERRY,STR     NaN         NaN
# 424                 BABYFOOD,FRUIT,APPL & RASPBERRY,JR     NaN         NaN
# 425             BABYFOOD,FRUIT & VEG,APPL & SWT POTATO     NaN         NaN
# 426         BABYFOOD,FRUIT,BANANAS&PNAPPL W/TAPIOCA,JR     NaN         NaN
# 427        BABYFOOD,FRUIT,BANANAS&PNAPPL W/TAPIOCA,STR     NaN         NaN
# 428                    BABYFOOD,FRUIT,PEARS&PNAPPL,STR     NaN         NaN
#
#     Survey Ref_desc  Refuse SciName  N_Factor  Pro_Factor  Fat_Factor  \
# 249    NaN      NaN     0.0     NaN      6.38         NaN         NaN
# 344      Y      NaN     0.0     NaN      6.25         NaN         NaN
# 345      Y      NaN     0.0     NaN      6.25        3.36        6.37
# 347      Y      NaN     0.0     NaN      6.25        3.60        8.37
# 394      Y      NaN     0.0     NaN      6.25         NaN         NaN
# 395      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 396      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 416      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 417      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 418      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 419      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 420      Y      NaN     0.0     NaN       NaN         NaN         NaN
# 421    NaN      NaN     0.0     NaN      6.25        3.36        8.37
# 422    NaN      NaN     0.0     NaN      6.25        3.36        8.37
# 423      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 424      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 425      Y      NaN     0.0     NaN       NaN         NaN         NaN
# 426      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 427      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 428      Y      NaN     0.0     NaN      6.25        3.36        8.37
#
#      CHO_Factor
# 249         NaN
# 344         NaN
# 345         3.6
# 347         3.6
# 394         NaN
# 395         3.6
# 396         3.6
# 416         3.6
# 417         3.6
# 418         3.6
# 419         3.6
# 420         NaN
# 421         3.6
# 422         3.6
# 423         3.6
# 424         3.6
# 425         NaN
# 426         3.6
# 427         3.6
# 428         3.6

# %% [markdown]
# As the results demonstrate, this method is a bit too simplistic:
# * what if there's a mis-spelling, either in the search term or in the record? Then this method will of course fail to find the desired results
# * what if the search term is contained as part of another word? For example `apple` matches with both `pineapple` and `applebee's` as much as it matches with literally `apple`, and there's no prioritization of search results to account for this kind of "common sense" considerations.
#
# We can address the first problem by using fuzzy string matching algorithms. There are different fuzzy matching algorithms with different pros and cons. Here are 5 different ones from Python's `fuzzywuzzy` package:
# * `fuzz.ratio`
# * `fuzz.partial_ratio`
# * `fuzz.token_sort_ratio`
# * `fuzz.token_set_ratio`
# * `process.extract`

# %%
SR_foods['score'] = SR_foods['Long_Desc'].apply(lambda x : fuzz.ratio('apple', x.lower()))
SR_foods.sort_values('score', ascending=False)[0:20]
# Out:
#       NDB_No  FdGrp_Cd               Long_Desc             Shrt_Desc  \
# 5349   18354      1800          Strudel, apple         STRUDEL,APPLE
# 1533    7951       700          Scrapple, pork         SCRAPPLE,PORK
# 1813    9077       900         Crabapples, raw        CRABAPPLES,RAW
# 2001    9312       900        Rose-apples, raw       ROSE-APPLES,RAW
# 7481   36019      3600       APPLEBEE'S, chili      APPLEBEE'S,CHILI
# 5258   18240      1800       Croissants, apple      CROISSANTS,APPLE
# 5778   19340      1900           Sugars, maple          SUGARS,MAPLE
# 5785   19353      1900           Syrups, maple          SYRUPS,MAPLE
# 5987   20069      2000               Triticale             TRITICALE
# 2598   11233      1100               Kale, raw              KALE,RAW
# 5793   19366      1900     Toppings, pineapple    TOPPINGS,PINEAPPLE
# 7610   42200      1600                   Papad                 PAPAD
# 7483   36021      3600    APPLEBEE'S, coleslaw   APPLEBEE'S,COLESLAW
# 5741   19294      1900    Fruit butters, apple   FRUIT BUTTERS,APPLE
# 5325   18323      1800              Pie, peach             PIE,PEACH
# 308     2047       200             Salt, table            SALT,TABLE
# 2044    9423       900             Prune puree           PRUNE PUREE
# 5084   18003      1800             Bagels, egg            BAGELS,EGG
# 436     3166       300  Babyfood, juice, apple  BABYFOOD,JUICE,APPLE
# 7680   43146      1100       Eggplant, pickled      EGGPLANT,PICKLED
#
#                       ComName ManufacName Survey  \
# 5349                      NaN         NaN      Y
# 1533                      NaN         NaN      Y
# 1813                      NaN         NaN    NaN
# 2001                      NaN         NaN    NaN
# 7481  family style, applebees  Applebee's    NaN
# 5258                      NaN         NaN    NaN
# 5778                      NaN         NaN      Y
# 5785                      NaN         NaN      Y
# 5987                      NaN         NaN    NaN
# 2598                      NaN         NaN    NaN
# 5793                      NaN         NaN      Y
# 7610                      NaN         NaN      Y
# 7483  applebees, family style  Applebee's    NaN
# 5741                      NaN         NaN      Y
# 5325                      NaN         NaN      Y
# 308                       NaN         NaN      Y
# 2044                      NaN         NaN    NaN
# 5084                      NaN         NaN    NaN
# 436                       NaN         NaN      Y
# 7680                      NaN         NaN      Y
#
#                                            Ref_desc  Refuse  \
# 5349                                            NaN     0.0
# 1533                                            NaN     0.0
# 1813                                 Core and stems     8.0
# 2001                                  Caps and pits    33.0
# 7481                                            NaN     0.0
# 5258                                            NaN     0.0
# 5778                                            NaN     0.0
# 5785                                            NaN     0.0
# 5987                                            NaN     0.0
# 2598  Stem ends, tough stems and tough midrib parts    28.0
# 5793                                            NaN     0.0
# 7610                                            NaN     0.0
# 7483                                            NaN     0.0
# 5741                                            NaN     0.0
# 5325                                            NaN     0.0
# 308                                             NaN     0.0
# 2044                                            NaN     0.0
# 5084                                            NaN     0.0
# 436                                             NaN     0.0
# 7680                                            NaN     0.0
#
#                                  SciName  N_Factor  Pro_Factor  Fat_Factor  \
# 5349                                 NaN      6.00        4.20        8.90
# 1533                                 NaN      6.25        4.00        9.00
# 1813                          Malus spp.      6.25        3.36        8.37
# 2001                     Syzygium jambos      6.25        3.36        8.37
# 7481                                 NaN       NaN         NaN         NaN
# 5258                                 NaN      5.90        4.00        8.80
# 5778                                 NaN      6.25        3.36        8.37
# 5785                                 NaN      6.25        3.36        8.37
# 5987                X Triticosecale spp.      5.83        3.32        8.37
# 2598  Brassica oleracea (Acephala Group)      6.25        2.44        8.37
# 5793                                 NaN      6.25        3.36        8.37
# 7610                                 NaN       NaN         NaN         NaN
# 7483                                 NaN       NaN         NaN         NaN
# 5741                                 NaN      6.25        4.00        9.00
# 5325                                 NaN      5.80        3.90        8.80
# 308                                  NaN      0.00         NaN         NaN
# 2044                                 NaN       NaN         NaN         NaN
# 5084                                 NaN      5.70        4.00        8.60
# 436                                  NaN      6.25        3.36        8.37
# 7680                                 NaN       NaN         NaN         NaN
#
#       CHO_Factor  score
# 5349        3.90     53
# 1533        4.00     53
# 1813        3.60     50
# 2001        3.60     48
# 7481         NaN     45
# 5258        4.00     45
# 5778        3.87     44
# 5785        3.87     44
# 5987        3.82     43
# 2598        3.57     43
# 5793        3.80     42
# 7610         NaN     40
# 7483         NaN     40
# 5741        4.00     40
# 5325        3.90     40
# 308          NaN     38
# 2044         NaN     38
# 5084        4.10     38
# 436         3.92     37
# 7680         NaN     36

# %%
SR_foods['score'] = SR_foods['Long_Desc'].apply(lambda x : fuzz.partial_ratio('apple', x.lower()))
SR_foods.sort_values('score', ascending=False)[0:20]
# Out:
#       NDB_No  FdGrp_Cd                                          Long_Desc  \
# 5741   19294      1900                               Fruit butters, apple
# 396     3117       300                Babyfood, fruit, applesauce, junior
# 456     3191       300  Babyfood, cereal, oatmeal, with applesauce and...
# 3904   14238      1400    Beverages, cranberry-apple juice drink, bottled
# 457     3192       300  Babyfood, cereal, oatmeal, with applesauce and...
# 442     3174       300       Babyfood, juice, orange and apple and banana
# 460     3195       300  Babyfood, cereal, rice, with applesauce and ba...
# 3941   14286      1400  Beverages, MOTTS, Apple juice light, fortified...
# 1688    8493       800     Cereals ready-to-eat, MALT-O-MEAL, Apple ZINGS
# 3944   14291      1400  Beverages, SNAPPLE, tea, black and green, read...
# 3947   14294      1400  Beverages, SNAPPLE, tea, black and green, read...
# 1840    9106       900  Fruit salad, (peach and pear and apricot and p...
# 1839    9104       900  Fruit salad, (peach and pear and apricot and p...
# 1838    9103       900  Fruit salad, (peach and pear and apricot and p...
# 1837    9102       900  Fruit salad, (peach and pear and apricot and p...
# 1836    9101       900  Fruit cocktail, (peach and pineapple and pear ...
# 1835    9100       900  Fruit cocktail, (peach and pineapple and pear ...
# 1834    9099       900  Fruit cocktail, (peach and pineapple and pear ...
# 1833    9098       900  Fruit cocktail, (peach and pineapple and pear ...
# 1763    9020       900        Applesauce, canned, sweetened, without salt
#
#                                               Shrt_Desc ComName  \
# 5741                                FRUIT BUTTERS,APPLE     NaN
# 396                          BABYFOOD,FRUIT,APPLSAUC,JR     NaN
# 456      BABYFOOD,CRL,OATMEAL,W/ APPLSAUC & BANANAS,STR     NaN
# 3904             BEVERAGES,CRANBERRY-APPLE JUC DRK,BTLD     NaN
# 457   BABYFOOD,CRL,OATMEAL,W/ APPLSAUC & BANANAS,JR,...     NaN
# 442                     BABYFOOD,JUC,ORANGE&APPL&BANANA     NaN
# 460         BABYFOOD,CRL,RICE,W/ APPLSAUC & BANANAS,STR     NaN
# 3941          BEVERAGES,MOTTS,APPL JUC LT,FORT W/ VIT C     NaN
# 1688                 CEREALS RTE,MALT-O-MEAL,APPL ZINGS     NaN
# 3944  BEVERAGES,SNAPPLE,TEA,BLACK & GRN,READY TO DRK...     NaN
# 3947  BEVERAGES,SNAPPLE,TEA,BLACK & GRN,READY TO DRK...     NaN
# 1840           FRUIT SALAD,CND,EX HVY SYRUP,SOL&LIQUIDS     NaN
# 1839               FRUIT SALAD,CND,LT SYRUP,SOL&LIQUIDS     NaN
# 1838                 FRUIT SALAD,CND,JUC PK,SOL&LIQUIDS     NaN
# 1837                 FRUIT SALAD,CND,H2O PK,SOL&LIQUIDS     NaN
# 1836        FRUIT COCKTAIL,CND,EX HVY SYRUP,SOL&LIQUIDS     NaN
# 1835           FRUIT COCKTAIL,CND,HVY SYRUP,SOL&LIQUIDS     NaN
# 1834            FRUIT COCKTAIL,CND,LT SYRUP,SOL&LIQUIDS     NaN
# 1833         FRUIT COCKTAIL,CND,EX LT SYRUP,SOL&LIQUIDS     NaN
# 1763                      APPLESAUCE,CND,SWTND,WO/ SALT     NaN
#
#                        ManufacName Survey Ref_desc  Refuse SciName  N_Factor  \
# 5741                           NaN      Y      NaN     0.0     NaN      6.25
# 396                            NaN      Y      NaN     0.0     NaN      6.25
# 456                            NaN      Y      NaN     0.0     NaN      6.04
# 3904                           NaN    NaN      NaN     0.0     NaN      6.25
# 457                            NaN      Y      NaN     0.0     NaN      6.04
# 442                            NaN      Y      NaN     0.0     NaN      6.25
# 460                            NaN      Y      NaN     0.0     NaN      6.00
# 3941                   Mott's INC.    NaN      NaN     0.0     NaN      6.25
# 1688                    MOM Brands    NaN      NaN     0.0     NaN      6.25
# 3944  Snapple Beverage Corporation    NaN      NaN     0.0     NaN      6.25
# 3947  Snapple Beverage Corporation    NaN      NaN     0.0     NaN      6.25
# 1840                           NaN    NaN      NaN     0.0     NaN      6.25
# 1839                           NaN    NaN      NaN     0.0     NaN      6.25
# 1838                           NaN    NaN      NaN     0.0     NaN      6.25
# 1837                           NaN    NaN      NaN     0.0     NaN      6.25
# 1836                           NaN    NaN      NaN     0.0     NaN      6.25
# 1835                           NaN      Y      NaN     0.0     NaN      6.25
# 1834                           NaN      Y      NaN     0.0     NaN      6.25
# 1833                           NaN    NaN      NaN     0.0     NaN      6.25
# 1763                           NaN      Y      NaN     0.0     NaN      6.25
#
#       Pro_Factor  Fat_Factor  CHO_Factor  score
# 5741        4.00        9.00        4.00    100
# 396         3.36        8.37        3.60    100
# 456         3.50        8.40        4.10    100
# 3904        3.36        8.37        3.90    100
# 457         3.50        8.40        4.10    100
# 442         3.36        8.37        3.92    100
# 460         3.80        8.40        4.20    100
# 3941         NaN         NaN         NaN    100
# 1688         NaN         NaN         NaN    100
# 3944         NaN         NaN         NaN    100
# 3947         NaN         NaN         NaN    100
# 1840        3.36        8.37        3.78    100
# 1839        3.36        8.37        3.71    100
# 1838        3.36        8.37        3.70    100
# 1837        3.36        8.37        3.60    100
# 1836        3.36        8.37        3.78    100
# 1835        3.36        8.37        3.75    100
# 1834        3.36        8.37        3.71    100
# 1833        3.36        8.37        3.69    100
# 1763        3.36        8.37        3.75    100

# %%
SR_foods['score'] = SR_foods['Long_Desc'].apply(lambda x : fuzz.token_sort_ratio('apple', x.lower()))
SR_foods.sort_values('score', ascending=False)[0:20]
# Out:
#       NDB_No  FdGrp_Cd               Long_Desc             Shrt_Desc  \
# 1533    7951       700          Scrapple, pork         SCRAPPLE,PORK
# 5349   18354      1800          Strudel, apple         STRUDEL,APPLE
# 1813    9077       900         Crabapples, raw        CRABAPPLES,RAW
# 2001    9312       900        Rose-apples, raw       ROSE-APPLES,RAW
# 7481   36019      3600       APPLEBEE'S, chili      APPLEBEE'S,CHILI
# 5258   18240      1800       Croissants, apple      CROISSANTS,APPLE
# 5778   19340      1900           Sugars, maple          SUGARS,MAPLE
# 5785   19353      1900           Syrups, maple          SYRUPS,MAPLE
# 2598   11233      1100               Kale, raw              KALE,RAW
# 5793   19366      1900     Toppings, pineapple    TOPPINGS,PINEAPPLE
# 5325   18323      1800              Pie, peach             PIE,PEACH
# 5987   20069      2000               Triticale             TRITICALE
# 7483   36021      3600    APPLEBEE'S, coleslaw   APPLEBEE'S,COLESLAW
# 290     2028       200         Spices, paprika               PAPRIKA
# 5741   19294      1900    Fruit butters, apple   FRUIT BUTTERS,APPLE
# 308     2047       200             Salt, table            SALT,TABLE
# 5084   18003      1800             Bagels, egg            BAGELS,EGG
# 7610   42200      1600                   Papad                 PAPAD
# 436     3166       300  Babyfood, juice, apple  BABYFOOD,JUICE,APPLE
# 6320   21416      2100       POPEYES, Coleslaw      POPEYES,COLESLAW
#
#                       ComName                   ManufacName Survey  \
# 1533                      NaN                           NaN      Y
# 5349                      NaN                           NaN      Y
# 1813                      NaN                           NaN    NaN
# 2001                      NaN                           NaN    NaN
# 7481  family style, applebees                    Applebee's    NaN
# 5258                      NaN                           NaN    NaN
# 5778                      NaN                           NaN      Y
# 5785                      NaN                           NaN      Y
# 2598                      NaN                           NaN    NaN
# 5793                      NaN                           NaN      Y
# 5325                      NaN                           NaN      Y
# 5987                      NaN                           NaN    NaN
# 7483  applebees, family style                    Applebee's    NaN
# 290                       NaN                           NaN      Y
# 5741                      NaN                           NaN      Y
# 308                       NaN                           NaN      Y
# 5084                      NaN                           NaN    NaN
# 7610                      NaN                           NaN      Y
# 436                       NaN                           NaN      Y
# 6320                      NaN  Popeyes Chicken and Biscuits    NaN
#
#                                            Ref_desc  Refuse  \
# 1533                                            NaN     0.0
# 5349                                            NaN     0.0
# 1813                                 Core and stems     8.0
# 2001                                  Caps and pits    33.0
# 7481                                            NaN     0.0
# 5258                                            NaN     0.0
# 5778                                            NaN     0.0
# 5785                                            NaN     0.0
# 2598  Stem ends, tough stems and tough midrib parts    28.0
# 5793                                            NaN     0.0
# 5325                                            NaN     0.0
# 5987                                            NaN     0.0
# 7483                                            NaN     0.0
# 290                                             NaN     0.0
# 5741                                            NaN     0.0
# 308                                             NaN     0.0
# 5084                                            NaN     0.0
# 7610                                            NaN     0.0
# 436                                             NaN     0.0
# 6320                                            NaN     0.0
#
#                                  SciName  N_Factor  Pro_Factor  Fat_Factor  \
# 1533                                 NaN      6.25        4.00        9.00
# 5349                                 NaN      6.00        4.20        8.90
# 1813                          Malus spp.      6.25        3.36        8.37
# 2001                     Syzygium jambos      6.25        3.36        8.37
# 7481                                 NaN       NaN         NaN         NaN
# 5258                                 NaN      5.90        4.00        8.80
# 5778                                 NaN      6.25        3.36        8.37
# 5785                                 NaN      6.25        3.36        8.37
# 2598  Brassica oleracea (Acephala Group)      6.25        2.44        8.37
# 5793                                 NaN      6.25        3.36        8.37
# 5325                                 NaN      5.80        3.90        8.80
# 5987                X Triticosecale spp.      5.83        3.32        8.37
# 7483                                 NaN       NaN         NaN         NaN
# 290                      Capsicum annuum      6.25        3.36        8.37
# 5741                                 NaN      6.25        4.00        9.00
# 308                                  NaN      0.00         NaN         NaN
# 5084                                 NaN      5.70        4.00        8.60
# 7610                                 NaN       NaN         NaN         NaN
# 436                                  NaN      6.25        3.36        8.37
# 6320                                 NaN       NaN         NaN         NaN
#
#       CHO_Factor  score
# 1533        4.00     56
# 5349        3.90     56
# 1813        3.60     53
# 2001        3.60     50
# 7481         NaN     48
# 5258        4.00     48
# 5778        3.87     47
# 5785        3.87     47
# 2598        3.57     46
# 5793        3.80     43
# 5325        3.90     43
# 5987        3.82     43
# 7483         NaN     42
# 290         2.35     42
# 5741        4.00     42
# 308          NaN     40
# 5084        4.10     40
# 7610         NaN     40
# 436         3.92     40
# 6320         NaN     38

# %%
SR_foods['score'] = SR_foods['Long_Desc'].apply(lambda x : fuzz.token_set_ratio('apple', x.lower()))
SR_foods.sort_values('score', ascending=False)[0:20]
# Out:
#       NDB_No  FdGrp_Cd                                          Long_Desc  \
# 3904   14238      1400    Beverages, cranberry-apple juice drink, bottled
# 3891   14220      1400  Beverages, OCEAN SPRAY, Cranberry-Apple Juice ...
# 3941   14286      1400  Beverages, MOTTS, Apple juice light, fortified...
# 534     3711       300  Babyfood, cereal, high protein, with apple and...
# 424     3153       300       Babyfood, fruit, apple and raspberry, junior
# 423     3152       300     Babyfood, fruit, apple and raspberry, strained
# 347     3025       300  Babyfood, GERBER, 3rd Foods, apple, mango and ...
# 345     3023       300  Babyfood, finger snacks, GERBER, GRADUATES, PU...
# 5258   18240      1800                                  Croissants, apple
# 5264   18246      1800  Danish pastry, fruit, enriched (includes apple...
# 5276   18262      1800  Muffins, English, raisin-cinnamon (includes ap...
# 5277   18263      1800  Muffins, English, raisin-cinnamon, toasted (in...
# 5307   18301      1800  Pie, apple, commercially prepared, enriched flour
# 468     3211       300  Babyfood, cereal, high protein, with apple and...
# 5349   18354      1800                                     Strudel, apple
# 5356   18362      1800  Toaster pastries, fruit (includes apple, blueb...
# 5404   18431      1800  Danish pastry, fruit, unenriched (includes app...
# 5413   18443      1800  Pie, apple, commercially prepared, unenriched ...
# 5472   18939      1800  Toaster pastries, fruit, toasted (include appl...
# 493     3269       300               Babyfood, juice, apple, with calcium
#
#                                               Shrt_Desc ComName  \
# 3904             BEVERAGES,CRANBERRY-APPLE JUC DRK,BTLD     NaN
# 3891  Beverages, OCEAN SPRAY, Cranberry-Apple Juice ...     NaN
# 3941          BEVERAGES,MOTTS,APPL JUC LT,FORT W/ VIT C     NaN
# 534   BABYFOOD,CRL,HI PROT,W/APPL&ORANGE,PREP W/WHL ...     NaN
# 424                  BABYFOOD,FRUIT,APPL & RASPBERRY,JR     NaN
# 423                 BABYFOOD,FRUIT,APPL & RASPBERRY,STR     NaN
# 347         BABYFOOD,GERBER,3RD FOODS,APPL,MANGO & KIWI     NaN
# 345   BABYFOOD,FINGER SNACKS,GERBER,GRADUATES,PUFFS,...     NaN
# 5258                                   CROISSANTS,APPLE     NaN
# 5264                            DANISH PASTRY,FRUIT,ENR     NaN
# 5276  MUFFINS,ENG,RAISIN-CINNAMON (INCLUDES APPLE-CI...     NaN
# 5277  MUFFINS,ENG,RAISIN-CINNAMON,TSTD (INCLUDES APP...     NaN
# 5307                       PIE,APPL,COMMLY PREP,ENR FLR     NaN
# 468              BABYFOOD,CRL,HI PROT,W/APPL&ORANGE,DRY     NaN
# 5349                                      STRUDEL,APPLE     NaN
# 5356                             TOASTER PASTRIES,FRUIT     NaN
# 5404  DANISH PASTRY,FRUIT,UNENR (INCL APPL,CINN,RAIS...     NaN
# 5413                     PIE,APPL,COMMLY PREP,UNENR FLR     NaN
# 5472  TSTR PSTRS,FRT,TSTD (INCL APPL,BLUEBERRY,CHERR...     NaN
# 493                              BABYFOOD,JUC,APPL,W/CA     NaN
#
#                         ManufacName Survey Ref_desc  Refuse SciName  N_Factor  \
# 3904                            NaN    NaN      NaN     0.0     NaN      6.25
# 3891  Ocean Spray Cranberries, Inc.    NaN      NaN     0.0     NaN      6.25
# 3941                    Mott's INC.    NaN      NaN     0.0     NaN      6.25
# 534                             NaN    NaN      NaN     0.0     NaN      0.00
# 424                             NaN      Y      NaN     0.0     NaN      6.25
# 423                             NaN      Y      NaN     0.0     NaN      6.25
# 347                          GERBER      Y      NaN     0.0     NaN      6.25
# 345                          GERBER      Y      NaN     0.0     NaN      6.25
# 5258                            NaN    NaN      NaN     0.0     NaN      5.90
# 5264                            NaN      Y      NaN     0.0     NaN      5.80
# 5276                            NaN      Y      NaN     0.0     NaN      6.25
# 5277                            NaN      Y      NaN     0.0     NaN       NaN
# 5307                            NaN      Y      NaN     0.0     NaN      5.70
# 468                             NaN    NaN      NaN     0.0     NaN      5.85
# 5349                            NaN      Y      NaN     0.0     NaN      6.00
# 5356                            NaN      Y      NaN     0.0     NaN      6.25
# 5404                            NaN    NaN      NaN     0.0     NaN      5.80
# 5413                            NaN    NaN      NaN     0.0     NaN      5.70
# 5472                            NaN    NaN      NaN     0.0     NaN       NaN
# 493                             NaN      Y      NaN     0.0     NaN       NaN
#
#       Pro_Factor  Fat_Factor  CHO_Factor  score
# 3904        3.36        8.37         3.9    100
# 3891         NaN         NaN         NaN    100
# 3941         NaN         NaN         NaN    100
# 534          NaN         NaN         NaN    100
# 424         3.36        8.37         3.6    100
# 423         3.36        8.37         3.6    100
# 347         3.60        8.37         3.6    100
# 345         3.36        6.37         3.6    100
# 5258        4.00        8.80         4.0    100
# 5264        4.10        8.80         3.9    100
# 5276        4.00        9.00         4.0    100
# 5277         NaN         NaN         NaN    100
# 5307        4.00        8.80         3.9    100
# 468         3.50        8.40         4.0    100
# 5349        4.20        8.90         3.9    100
# 5356         NaN         NaN         NaN    100
# 5404        4.10        8.80         3.9    100
# 5413        4.00        8.80         3.9    100
# 5472         NaN         NaN         NaN    100
# 493          NaN         NaN         NaN    100

# %%
match_list = process.extract('apple',SR_foods['Long_Desc'], limit=None)
match_list[0:50]
# Out:
# [('Babyfood, apples, dices, toddler', 90, 394),
#  ('Babyfood, fruit, applesauce, strained', 90, 395),
#  ('Babyfood, fruit, applesauce, junior', 90, 396),
#  ('Babyfood, juice, apple', 90, 436),
#  ('Babyfood, apple-banana juice', 90, 437),
#  ('Babyfood, juice, apple and peach', 90, 438),
#  ('Babyfood, juice, apple and prune', 90, 439),
#  ('Babyfood, juice, orange and apple', 90, 441),
#  ('Babyfood, juice, orange and pineapple', 90, 445),
#  ('Babyfood, dessert, dutch apple, strained', 90, 475),
#  ('Babyfood, dessert, dutch apple, junior', 90, 476),
#  ('Babyfood, juice, apple and grape', 90, 491),
#  ('Babyfood, juice, apple, with calcium', 90, 493),
#  ('Babyfood, apples with ham, strained', 90, 502),
#  ('Scrapple, pork', 90, 1533),
#  ('Apples, raw, without skin', 90, 1748),
#  ('Apples, dried, sulfured, uncooked', 90, 1754),
#  ('Crabapples, raw', 90, 1813),
#  ("Custard-apple, (bullock's-heart), raw", 90, 1821),
#  ('Mammy-apple, (mamey), raw', 90, 1891),
#  ('Pineapple, raw, all varieties', 90, 1960),
#  ('Pineapple, frozen, chunks, sweetened', 90, 1966),
#  ('Rose-apples, raw', 90, 2001),
#  ('Sugar-apples, (sweetsop), raw', 90, 2009),
#  ('Pineapple, canned, juice pack, drained', 90, 2019),
#  ('Applesauce, canned, sweetened, with salt', 90, 2029),
#  ('Pineapple, raw, traditional varieties', 90, 2048),
#  ('Pineapple, raw, extra sweet variety', 90, 2049),
#  ('Orange Pineapple Juice Blend', 90, 2064),
#  ('Apples, raw, golden delicious, with skin', 90, 2066),
#  ('Croissants, apple', 90, 5258),
#  ('Pie, apple, prepared from recipe', 90, 5308),
#  ('Strudel, apple', 90, 5349),
#  ('Pie, Dutch Apple, Commercially Prepared', 90, 5476),
#  ('Fruit butters, apple', 90, 5741),
#  ('Pie fillings, apple, canned', 90, 5755),
#  ('Toppings, pineapple', 90, 5793),
#  ("APPLEBEE'S, 9 oz house sirloin steak", 90, 7462),
#  ("APPLEBEE'S, Double Crunch Shrimp", 90, 7463),
#  ("APPLEBEE'S, french fries", 90, 7464),
#  ("APPLEBEE'S, mozzarella sticks", 90, 7466),
#  ("APPLEBEE'S, fish, hand battered", 90, 7480),
#  ("APPLEBEE'S, chili", 90, 7481),
#  ("APPLEBEE'S, coleslaw", 90, 7483),
#  ("APPLEBEE'S, crunchy onion rings", 90, 7484),
#  ("APPLEBEE'S, chicken tenders platter", 90, 7485),
#  ('Babyfood, apple yogurt dessert, strained', 90, 7590),
#  ('Babyfood, juice, apple-sweet potato', 90, 7623),
#  ('Babyfood, rice and apples, dry', 90, 7758),
#  ('Babyfood, juice, apple - cherry', 90, 7759)]

# %% [markdown]
# `process.extract` maybe performs the best at getting literal `apples` to be near the top of the search results but still has some trouble favoring that over results like `pineapple`, `applesauce` and `applebee's`. Rather than digging into the fuzzy matching algorithms which are pretty complex, a simpler solution to improve the results would be to cascade other comparisons going from more exact to less exact matching.

# %%
# everything is case-insensitive
def new_score(search, name, score):
    # exact match
    if search.lower() == name.lower():
        modifier = 3
    # exact match of substring, *isolated*
    # for example 'apple' should match with 'apple, raw' but not 'pineapple'
    elif re.match(r'.*(^|[^a-zA-Z0-9]+)'+search+r'($|[^a-zA-Z0-9]+)',name, re.IGNORECASE):
        modifier = 2
    # simple '-s' plurals
    elif re.match(r'.*(^|[^a-zA-Z0-9]+)'+search+r's($|[^a-zA-Z0-9]+)',name, re.IGNORECASE):
        modifier = 1
    else:
        modifier = 0
    return modifier + score/100

[(name, new_score('egg',name,20)) for name in ['egg','legg','eggs','egg, white', 'eggs, white', ' egg ', ' egg', 'eggo', 'EGG', 'LEGG', 'EGGS', 'EGG, S', ' EGG ', 'EGGO']]
# Out:
# [('egg', 3.2),
#  ('legg', 0.2),
#  ('eggs', 1.2),
#  ('egg, white', 2.2),
#  ('eggs, white', 1.2),
#  (' egg ', 2.2),
#  (' egg', 2.2),
#  ('eggo', 0.2),
#  ('EGG', 3.2),
#  ('LEGG', 0.2),
#  ('EGGS', 1.2),
#  ('EGG, S', 2.2),
#  (' EGG ', 2.2),
#  ('EGGO', 0.2)]

# %% [markdown]
# With this new cascading scoring method we can see that `egg` matches better than `egg, white` which matches better than `eggs, white` which matches better than `eggo` and `legg`.

# %%
def sort_criteria(item):
    _, score, _ = item
    return score

new_matches = [(name, new_score('egg', name, score), idx) for name, score, idx in match_list]
new_matches.sort(key=sort_criteria, reverse=True)
new_matches[0:50]
# Out:
# [('Egg, whole, cooked, scrambled', 2.54, 122),
#  ('Fast foods, egg, scrambled', 2.54, 6117),
#  ('Egg rolls, vegetable, frozen, prepared', 2.54, 6446),
#  ('Babyfood, cereal, with egg yolks, junior', 2.51, 462),
#  ('Wonton wrappers (includes egg roll wrappers)', 2.48, 5361),
#  ('Bagels, egg', 2.38, 5084),
#  ('Egg, whole, raw, fresh', 2.36, 113),
#  ('Egg, yolk, raw, frozen, pasteurized', 2.36, 116),
#  ('Egg, whole, cooked, fried', 2.36, 118),
#  ('Egg, whole, cooked, hard-boiled', 2.36, 119),
#  ('Egg, whole, cooked, omelet', 2.36, 120),
#  ('Egg, whole, cooked, poached', 2.36, 121),
#  ('Egg, whole, dried', 2.36, 123),
#  ('Egg, duck, whole, fresh, raw', 2.36, 128),
#  ('Egg, goose, whole, fresh, raw', 2.36, 129),
#  ('Egg, quail, whole, fresh, raw', 2.36, 130),
#  ('Egg, turkey, whole, fresh, raw', 2.36, 131),
#  ('Egg substitute, powder', 2.36, 132),
#  ('Egg, yolk, raw, frozen, salted, pasteurized', 2.36, 144),
#  ('Egg, white, raw, frozen, pasteurized', 2.36, 154),
#  ('Egg, whole, raw, frozen, salted, pasteurized', 2.36, 216),
#  ('Babyfood, cereal, egg yolks and bacon, junior', 2.36, 464),
#  ('Bread, egg', 2.36, 5103),
#  ('Bread, egg, toasted', 2.36, 5104),
#  ('Crackers, matzo, egg', 2.36, 5237),
#  ('Pie, egg custard, commercially prepared', 2.36, 5320),
#  ('Crackers, matzo, egg and onion', 2.36, 5379),
#  ('Noodles, egg, dry, enriched', 2.36, 6017),
#  ('Noodles, egg, enriched, cooked', 2.36, 6018),
#  ('Noodles, egg, spinach, enriched, dry', 2.36, 6019),
#  ('Noodles, egg, spinach, enriched, cooked', 2.36, 6020),
#  ('Noodles, egg, dry, unenriched', 2.36, 6062),
#  ("McDONALD'S, Egg McMUFFIN", 2.36, 6283),
#  ("McDONALD'S, Sausage McMUFFIN with Egg", 2.36, 6285),
#  ("McDONALD'S, Bacon Egg & Cheese Biscuit", 2.36, 6286),
#  ("McDONALD'S, Sausage Biscuit with Egg", 2.36, 6288),
#  ('Egg rolls, pork, refrigerated, heated', 2.36, 6444),
#  ('Egg rolls, chicken, refrigerated, heated', 2.36, 6445),
#  ('Potato salad with egg', 2.36, 6457),
#  ('Soup, egg drop, Chinese restaurant', 2.36, 7108),
#  ('Babyfood, cereal, with egg yolks, strained', 2.34, 461),
#  ('Pasta, homemade, made with egg, cooked', 2.34, 6013),
#  ('Egg, yolk, raw, frozen, sugared, pasteurized', 2.24, 117),
#  ('Egg, whole, dried, stabilized, glucose reduced', 2.24, 124),
#  ('Egg, white, dried, flakes, stabilized, glucose reduced', 2.24, 125),
#  ('Egg, white, dried, powder, stabilized, glucose reduced', 2.24, 126),
#  ("Egg, whole, raw, frozen, pasteurized (Includes foods for USDA's Food Distribution Program)",
#   2.24,
#   153),
#  ('Egg, white, dried, stabilized, glucose reduced', 2.24, 218),
#  ('Desserts, egg custard, baked, prepared-from-recipe', 2.24, 5653),
#  ('Egg custards, dry mix, prepared with whole milk', 2.24, 5655)]

# %%
match_list2 = process.extract('apple',SR_foods['Long_Desc'], limit=None)
match_list2[0:50]
# Out:
# [('Babyfood, apples, dices, toddler', 90, 394),
#  ('Babyfood, fruit, applesauce, strained', 90, 395),
#  ('Babyfood, fruit, applesauce, junior', 90, 396),
#  ('Babyfood, juice, apple', 90, 436),
#  ('Babyfood, apple-banana juice', 90, 437),
#  ('Babyfood, juice, apple and peach', 90, 438),
#  ('Babyfood, juice, apple and prune', 90, 439),
#  ('Babyfood, juice, orange and apple', 90, 441),
#  ('Babyfood, juice, orange and pineapple', 90, 445),
#  ('Babyfood, dessert, dutch apple, strained', 90, 475),
#  ('Babyfood, dessert, dutch apple, junior', 90, 476),
#  ('Babyfood, juice, apple and grape', 90, 491),
#  ('Babyfood, juice, apple, with calcium', 90, 493),
#  ('Babyfood, apples with ham, strained', 90, 502),
#  ('Scrapple, pork', 90, 1533),
#  ('Apples, raw, without skin', 90, 1748),
#  ('Apples, dried, sulfured, uncooked', 90, 1754),
#  ('Crabapples, raw', 90, 1813),
#  ("Custard-apple, (bullock's-heart), raw", 90, 1821),
#  ('Mammy-apple, (mamey), raw', 90, 1891),
#  ('Pineapple, raw, all varieties', 90, 1960),
#  ('Pineapple, frozen, chunks, sweetened', 90, 1966),
#  ('Rose-apples, raw', 90, 2001),
#  ('Sugar-apples, (sweetsop), raw', 90, 2009),
#  ('Pineapple, canned, juice pack, drained', 90, 2019),
#  ('Applesauce, canned, sweetened, with salt', 90, 2029),
#  ('Pineapple, raw, traditional varieties', 90, 2048),
#  ('Pineapple, raw, extra sweet variety', 90, 2049),
#  ('Orange Pineapple Juice Blend', 90, 2064),
#  ('Apples, raw, golden delicious, with skin', 90, 2066),
#  ('Croissants, apple', 90, 5258),
#  ('Pie, apple, prepared from recipe', 90, 5308),
#  ('Strudel, apple', 90, 5349),
#  ('Pie, Dutch Apple, Commercially Prepared', 90, 5476),
#  ('Fruit butters, apple', 90, 5741),
#  ('Pie fillings, apple, canned', 90, 5755),
#  ('Toppings, pineapple', 90, 5793),
#  ("APPLEBEE'S, 9 oz house sirloin steak", 90, 7462),
#  ("APPLEBEE'S, Double Crunch Shrimp", 90, 7463),
#  ("APPLEBEE'S, french fries", 90, 7464),
#  ("APPLEBEE'S, mozzarella sticks", 90, 7466),
#  ("APPLEBEE'S, fish, hand battered", 90, 7480),
#  ("APPLEBEE'S, chili", 90, 7481),
#  ("APPLEBEE'S, coleslaw", 90, 7483),
#  ("APPLEBEE'S, crunchy onion rings", 90, 7484),
#  ("APPLEBEE'S, chicken tenders platter", 90, 7485),
#  ('Babyfood, apple yogurt dessert, strained', 90, 7590),
#  ('Babyfood, juice, apple-sweet potato', 90, 7623),
#  ('Babyfood, rice and apples, dry', 90, 7758),
#  ('Babyfood, juice, apple - cherry', 90, 7759)]

# %%
new_matches2 = [(name, new_score('apple', name, score), idx) for name, score, idx in match_list2]
new_matches2.sort(key=sort_criteria, reverse=True)
new_matches2[0:50]
# Out:
# [('Babyfood, juice, apple', 2.9, 436),
#  ('Babyfood, apple-banana juice', 2.9, 437),
#  ('Babyfood, juice, apple and peach', 2.9, 438),
#  ('Babyfood, juice, apple and prune', 2.9, 439),
#  ('Babyfood, juice, orange and apple', 2.9, 441),
#  ('Babyfood, dessert, dutch apple, strained', 2.9, 475),
#  ('Babyfood, dessert, dutch apple, junior', 2.9, 476),
#  ('Babyfood, juice, apple and grape', 2.9, 491),
#  ('Babyfood, juice, apple, with calcium', 2.9, 493),
#  ("Custard-apple, (bullock's-heart), raw", 2.9, 1821),
#  ('Mammy-apple, (mamey), raw', 2.9, 1891),
#  ('Croissants, apple', 2.9, 5258),
#  ('Pie, apple, prepared from recipe', 2.9, 5308),
#  ('Strudel, apple', 2.9, 5349),
#  ('Pie, Dutch Apple, Commercially Prepared', 2.9, 5476),
#  ('Fruit butters, apple', 2.9, 5741),
#  ('Pie fillings, apple, canned', 2.9, 5755),
#  ('Babyfood, apple yogurt dessert, strained', 2.9, 7590),
#  ('Babyfood, juice, apple-sweet potato', 2.9, 7623),
#  ('Babyfood, juice, apple - cherry', 2.9, 7759),
#  ('Babyfood, banana apple dessert, strained', 2.9, 7767),
#  ('Babyfood, GERBER, 2nd Foods, apple, carrot and squash, organic', 2.6, 344),
#  ('Babyfood, finger snacks, GERBER, GRADUATES, PUFFS, apple and cinnamon',
#   2.6,
#   345),
#  ('Babyfood, GERBER, 3rd Foods, apple, mango and kiwi', 2.6, 347),
#  ('Babyfood, fruit, apple and raspberry, strained', 2.6, 423),
#  ('Babyfood, fruit, apple and raspberry, junior', 2.6, 424),
#  ('Babyfood, fruit and vegetable, apple and sweet potato', 2.6, 425),
#  ('Babyfood, fruit, apple and blueberry, strained', 2.6, 434),
#  ('Babyfood, fruit, apple and blueberry, junior', 2.6, 435),
#  ('Babyfood, juice, orange and apple and banana', 2.6, 442),
#  ('Babyfood, cereal, high protein, with apple and orange, dry', 2.6, 468),
#  ('Babyfood, cereal, high protein, with apple and orange, prepared with whole milk',
#   2.6,
#   534),
#  ('Cereals ready-to-eat, MALT-O-MEAL, Apple ZINGS', 2.6, 1688),
#  ('Cereals ready-to-eat, QUAKER, Natural Granola Apple Cranberry Almond',
#   2.6,
#   1714),
#  ('Cereals, QUAKER, Instant Oatmeal, Apple and Cinnamon, reduced sugar',
#   2.6,
#   1722),
#  ('Cereals, QUAKER, oatmeal, REAL MEDLEYS, apple walnut, dry', 2.6, 1739),
#  ('Apple juice, canned or bottled, unsweetened, without added ascorbic acid',
#   2.6,
#   1759),
#  ('Apple juice, frozen concentrate, unsweetened, undiluted, without added ascorbic acid',
#   2.6,
#   1760),
#  ('Apple juice, frozen concentrate, unsweetened, diluted with 3 volume water without added ascorbic acid',
#   2.6,
#   1761),
#  ('Apple juice, canned or bottled, unsweetened, with added ascorbic acid',
#   2.6,
#   2027),
#  ('Apple juice, frozen concentrate, unsweetened, undiluted, with added ascorbic acid',
#   2.6,
#   2034),
#  ('Apple juice, frozen concentrate, unsweetened, diluted with 3 volume water, with added ascorbic acid',
#   2.6,
#   2035),
#  ('Juice, apple and grape blend, with added ascorbic acid', 2.6, 2056),
#  ('Juice, apple, grape and pear blend, with added ascorbic acid and calcium',
#   2.6,
#   2057),
#  ('Apple juice, canned or bottled, unsweetened, with added ascorbic acid, calcium, and potassium',
#   2.6,
#   2080),
#  ('Ruby Red grapefruit juice blend (grapefruit, grape, apple), OCEAN SPRAY, bottled, with added vitamin C',
#   2.6,
#   2089),
#  ('Beverages, Apple juice drink, light, fortified with vitamin C', 2.6, 3847),
#  ('Beverages, OCEAN SPRAY, Cranberry-Apple Juice Drink, bottled', 2.6, 3891),
#  ('Beverages, cranberry-apple juice drink, bottled', 2.6, 3904),
#  ('Beverages, MOTTS, Apple juice light, fortified with vitamin C', 2.6, 3941)]

# %% [markdown]
# Does pretty good, it eliminates matches like `pineapple` and `applebee's` for the search term `apple` but now we should prioritize those that match more primary categories as well as those that match isolated terms rather than compound terms, ex.. the following is an appropriate ordering for the search `apple`:
#
# * `Apples, raw, without skin`
# * `Apple juice, canned or bottled, unsweetened, without added ascorbic acid`
# * `Babyfood, juice, apple`

# %%
SR_foods[SR_foods['Long_Desc'].str.contains('apple', case=False)][0:20]
# Out:
#      NDB_No  FdGrp_Cd                                          Long_Desc  \
# 249    1304       100          Yogurt, Greek, 2% fat, pineapple, CHOBANI
# 344    3022       300  Babyfood, GERBER, 2nd Foods, apple, carrot and...
# 345    3023       300  Babyfood, finger snacks, GERBER, GRADUATES, PU...
# 347    3025       300  Babyfood, GERBER, 3rd Foods, apple, mango and ...
# 394    3115       300                   Babyfood, apples, dices, toddler
# 395    3116       300              Babyfood, fruit, applesauce, strained
# 396    3117       300                Babyfood, fruit, applesauce, junior
# 416    3142       300  Babyfood, fruit, applesauce and apricots, stra...
# 417    3143       300   Babyfood, fruit, applesauce and apricots, junior
# 418    3144       300  Babyfood, fruit, applesauce and cherries, stra...
# 419    3145       300   Babyfood, fruit, applesauce and cherries, junior
# 420    3147       300    Babyfood, fruit, applesauce with banana, junior
# 421    3150       300  Babyfood, fruit, applesauce and pineapple, str...
# 422    3151       300  Babyfood, fruit, applesauce and pineapple, junior
# 423    3152       300     Babyfood, fruit, apple and raspberry, strained
# 424    3153       300       Babyfood, fruit, apple and raspberry, junior
# 425    3154       300  Babyfood, fruit and vegetable, apple and sweet...
# 426    3156       300  Babyfood, fruit, bananas and pineapple with ta...
# 427    3157       300  Babyfood, fruit, bananas and pineapple with ta...
# 428    3158       300     Babyfood, fruit, pears and pineapple, strained
#
#                                              Shrt_Desc ComName ManufacName  \
# 249                 YOGURT,GREEK,2% FAT,PNAPPL,CHOBANI     NaN     Chobani
# 344  BABYFOOD,GERBER,2ND FOODS,APPL,CARROT & SQUASH...     NaN         NaN
# 345  BABYFOOD,FINGER SNACKS,GERBER,GRADUATES,PUFFS,...     NaN      GERBER
# 347        BABYFOOD,GERBER,3RD FOODS,APPL,MANGO & KIWI     NaN      GERBER
# 394                          BABYFOOD,APPLS,DICES,TODD     NaN         NaN
# 395                        BABYFOOD,FRUIT,APPLSAUC,STR     NaN         NaN
# 396                         BABYFOOD,FRUIT,APPLSAUC,JR     NaN         NaN
# 416               BABYFOOD,FRUIT,APPLSAUC&APRICOTS,STR     NaN         NaN
# 417                BABYFOOD,FRUIT,APPLSAUC&APRICOTS,JR     NaN         NaN
# 418               BABYFOOD,FRUIT,APPLSAUC&CHERRIES,STR     NaN         NaN
# 419              BABYFOOD,FRUIT,APPLSAUC & CHERRIES,JR     NaN         NaN
# 420                BABYFOOD,FRUIT,APPLSAUC W/BANANA,JR     NaN         NaN
# 421                 BABYFOOD,FRUIT,APPLSAUC&PNAPPL,STR     NaN         NaN
# 422                  BABYFOOD,FRUIT,APPLSAUC&PNAPPL,JR     NaN         NaN
# 423                BABYFOOD,FRUIT,APPL & RASPBERRY,STR     NaN         NaN
# 424                 BABYFOOD,FRUIT,APPL & RASPBERRY,JR     NaN         NaN
# 425             BABYFOOD,FRUIT & VEG,APPL & SWT POTATO     NaN         NaN
# 426         BABYFOOD,FRUIT,BANANAS&PNAPPL W/TAPIOCA,JR     NaN         NaN
# 427        BABYFOOD,FRUIT,BANANAS&PNAPPL W/TAPIOCA,STR     NaN         NaN
# 428                    BABYFOOD,FRUIT,PEARS&PNAPPL,STR     NaN         NaN
#
#     Survey Ref_desc  Refuse SciName  N_Factor  Pro_Factor  Fat_Factor  \
# 249    NaN      NaN     0.0     NaN      6.38         NaN         NaN
# 344      Y      NaN     0.0     NaN      6.25         NaN         NaN
# 345      Y      NaN     0.0     NaN      6.25        3.36        6.37
# 347      Y      NaN     0.0     NaN      6.25        3.60        8.37
# 394      Y      NaN     0.0     NaN      6.25         NaN         NaN
# 395      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 396      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 416      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 417      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 418      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 419      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 420      Y      NaN     0.0     NaN       NaN         NaN         NaN
# 421    NaN      NaN     0.0     NaN      6.25        3.36        8.37
# 422    NaN      NaN     0.0     NaN      6.25        3.36        8.37
# 423      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 424      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 425      Y      NaN     0.0     NaN       NaN         NaN         NaN
# 426      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 427      Y      NaN     0.0     NaN      6.25        3.36        8.37
# 428      Y      NaN     0.0     NaN      6.25        3.36        8.37
#
#      CHO_Factor  score
# 249         NaN     24
# 344         NaN    100
# 345         3.6    100
# 347         3.6    100
# 394         NaN     29
# 395         3.6     26
# 396         3.6     27
# 416         3.6     19
# 417         3.6     20
# 418         3.6     19
# 419         3.6     20
# 420         NaN     20
# 421         3.6     19
# 422         3.6     20
# 423         3.6    100
# 424         3.6    100
# 425         NaN    100
# 426         3.6     16
# 427         3.6     16
# 428         3.6     21

# %%
SR_foods[SR_foods['Shrt_Desc'].str.contains('apple', case=False)][0:20]
# Out:
#       NDB_No  FdGrp_Cd                                          Long_Desc  \
# 436     3166       300                             Babyfood, juice, apple
# 437     3167       300                       Babyfood, apple-banana juice
# 1533    7951       700                                     Scrapple, pork
# 1747    9003       900  Apples, raw, with skin (Includes foods for USD...
# 1748    9004       900                          Apples, raw, without skin
# 1749    9005       900          Apples, raw, without skin, cooked, boiled
# 1750    9006       900       Apples, raw, without skin, cooked, microwave
# 1751    9008       900  Apples, canned, sweetened, sliced, drained, he...
# 1752    9009       900  Apples, dehydrated (low moisture), sulfured, u...
# 1753    9010       900  Apples, dehydrated (low moisture), sulfured, s...
# 1754    9011       900                  Apples, dried, sulfured, uncooked
# 1755    9012       900  Apples, dried, sulfured, stewed, without added...
# 1756    9013       900  Apples, dried, sulfured, stewed, with added sugar
# 1757    9014       900  Apples, frozen, unsweetened, unheated (Include...
# 1758    9015       900  Apples, frozen, unsweetened, heated (Includes ...
# 1759    9016       900  Apple juice, canned or bottled, unsweetened, w...
# 1760    9017       900  Apple juice, frozen concentrate, unsweetened, ...
# 1761    9018       900  Apple juice, frozen concentrate, unsweetened, ...
# 1762    9019       900  Applesauce, canned, unsweetened, without added...
# 1763    9020       900        Applesauce, canned, sweetened, without salt
#
#                                               Shrt_Desc ComName ManufacName  \
# 436                                BABYFOOD,JUICE,APPLE     NaN         NaN
# 437                           BABYFOOD,APPLE-BANANA JUC     NaN         NaN
# 1533                                      SCRAPPLE,PORK     NaN         NaN
# 1747                               APPLES,RAW,WITH SKIN     NaN         NaN
# 1748                            APPLES,RAW,WITHOUT SKIN     NaN         NaN
# 1749                          APPLES,RAW,WO/SKN,CKD,BLD     NaN         NaN
# 1750                   APPLES,RAW,WO/ SKN,CKD,MICROWAVE     NaN         NaN
# 1751                   APPLES,CND,SWTND,SLICED,DRND,HTD     NaN         NaN
# 1752             APPLES,DEHYD (LO MOIST),SULFURED,UNCKD     NaN         NaN
# 1753              APPLES,DEHYD (LO MOIST),SULFURED,STWD     NaN         NaN
# 1754                        APPLES,DRIED,SULFURED,UNCKD     NaN         NaN
# 1755               APPLES,DRIED,SULFURED,STWD,WO/ SUGAR     NaN         NaN
# 1756                APPLES,DRIED,SULFURED,STWD,W/ SUGAR     NaN         NaN
# 1757                           APPLES,FRZ,UNSWTND,UNHTD     NaN         NaN
# 1758                             APPLES,FRZ,UNSWTND,HTD     NaN         NaN
# 1759      APPLE JUC,CND OR BTLD,UNSWTND,WO/ ADDED VIT C     NaN         NaN
# 1760         APPLE JUC,FRZ CONC,UNSWTND,UNDIL,WO/ VIT C     NaN         NaN
# 1761  APPLE JUC,FRZ CONC,UNSWTND,DIL W/3 VOLUME H2O ...     NaN         NaN
# 1762             APPLESAUCE,CND,UNSWTND,WO/ ADDED VIT C     NaN         NaN
# 1763                      APPLESAUCE,CND,SWTND,WO/ SALT     NaN         NaN
#
#      Survey                     Ref_desc  Refuse          SciName  N_Factor  \
# 436       Y                          NaN     0.0              NaN      6.25
# 437       Y                          NaN     0.0              NaN       NaN
# 1533      Y                          NaN     0.0              NaN      6.25
# 1747      Y                Core and stem    10.0  Malus domestica      6.25
# 1748      Y  10% core and stem, 13% skin    23.0  Malus domestica      6.25
# 1749      Y                          NaN     0.0              NaN      6.25
# 1750      Y                          NaN     0.0              NaN      6.25
# 1751      Y                          NaN     0.0              NaN      6.25
# 1752      Y                          NaN     0.0              NaN      6.25
# 1753    NaN                          NaN     0.0              NaN      6.25
# 1754      Y                          NaN     0.0              NaN      6.25
# 1755      Y                          NaN     0.0              NaN      6.25
# 1756    NaN                          NaN     0.0              NaN      6.25
# 1757    NaN                          NaN     0.0              NaN      6.25
# 1758    NaN                          NaN     0.0              NaN      6.25
# 1759      Y                          NaN     0.0              NaN      6.25
# 1760      Y                          NaN     0.0              NaN      6.25
# 1761      Y                          NaN     0.0              NaN      6.25
# 1762      Y                          NaN     0.0              NaN      6.25
# 1763      Y                          NaN     0.0              NaN      6.25
#
#       Pro_Factor  Fat_Factor  CHO_Factor  score
# 436         3.36        8.37        3.92    100
# 437          NaN         NaN         NaN    100
# 1533        4.00        9.00        4.00     56
# 1747        3.36        8.37        3.60     13
# 1748        3.36        8.37        3.60     36
# 1749        3.36        8.37        3.60     24
# 1750        3.36        8.37        3.60     22
# 1751        3.36        8.37        3.70     20
# 1752        3.36        8.37        3.60     19
# 1753        3.36        8.37        3.60     20
# 1754        3.36        8.37        3.60     29
# 1755        3.36        8.37        3.60     19
# 1756         NaN         NaN         NaN     20
# 1757        3.36        8.37        3.60     11
# 1758        3.36        8.37        3.60     11
# 1759        3.36        8.37        3.92    100
# 1760        3.36        8.37        3.92    100
# 1761        3.36        8.37        3.92    100
# 1762        3.36        8.37        3.60      9
# 1763        3.36        8.37        3.75     22

# %%
SR_foods[SR_foods['ComName'].fillna("").str.contains('apple', case=False)][0:20]
# Out:
#       NDB_No  FdGrp_Cd                                          Long_Desc  \
# 7317   35027      3500                  Cloudberries, raw (Alaska Native)
# 7462   36000      3600               APPLEBEE'S, 9 oz house sirloin steak
# 7463   36001      3600                   APPLEBEE'S, Double Crunch Shrimp
# 7464   36002      3600                           APPLEBEE'S, french fries
# 7465   36003      3600  APPLEBEE'S, KRAFT, Macaroni & Cheese, from kid...
# 7466   36004      3600                      APPLEBEE'S, mozzarella sticks
# 7467   36005      3600       APPLEBEE'S, chicken tenders, from kids' menu
# 7480   36018      3600                    APPLEBEE'S, fish, hand battered
# 7481   36019      3600                                  APPLEBEE'S, chili
# 7483   36021      3600                               APPLEBEE'S, coleslaw
# 7484   36022      3600                    APPLEBEE'S, crunchy onion rings
# 7485   36023      3600                APPLEBEE'S, chicken tenders platter
#
#                                             Shrt_Desc  \
# 7317                 CLOUDBERRIES,RAW (ALASKA NATIVE)
# 7462              APPLEBEE'S,9 OZ HOUSE SIRLOIN STEAK
# 7463                  APPLEBEE'S,DOUBLE CRUNCH SHRIMP
# 7464                             APPLEBEE'S,FRENCH FR
# 7465  APPLEBEE'S,KRAFT,MACARONI & CHS,FROM KID'S MENU
# 7466                       APPLEBEE'S,MOZZARELLA STKS
# 7467         APPLEBEE'S,CHICK TENDERS,FROM KIDS' MENU
# 7480                    APPLEBEE'S,FISH,HAND BATTERED
# 7481                                 APPLEBEE'S,CHILI
# 7483                              APPLEBEE'S,COLESLAW
# 7484                   APPLEBEE'S,CRUNCHY ONION RINGS
# 7485                 APPLEBEE'S,CHICK TENDERS PLATTER
#
#                                           ComName ManufacName Survey Ref_desc  \
# 7317  baked apple berry, yellowberry, salmonberry         NaN    NaN      NaN
# 7462                      family style, applebees  Applebee's    NaN      NaN
# 7463                      family style, applebees  Applebee's    NaN      NaN
# 7464                      family style, applebees  Applebee's    NaN      NaN
# 7465                      family style, applebees  Applebee's    NaN      NaN
# 7466                      family style, applebees  Applebee's    NaN      NaN
# 7467                      family style, applebees  Applebee's    NaN      NaN
# 7480                      applebees, family style  Applebee's    NaN      NaN
# 7481                      family style, applebees  Applebee's    NaN      NaN
# 7483                      applebees, family style  Applebee's    NaN      NaN
# 7484                      applebees, family style  Applebee's    NaN      NaN
# 7485                      family style, applebees  Applebee's    NaN      NaN
#
#       Refuse               SciName  N_Factor  Pro_Factor  Fat_Factor  \
# 7317     0.0  Rubus chamaemorus L.       5.3         NaN         NaN
# 7462     0.0                   NaN       NaN         NaN         NaN
# 7463     0.0                   NaN       NaN         NaN         NaN
# 7464     0.0                   NaN       NaN         NaN         NaN
# 7465     0.0                   NaN       NaN         NaN         NaN
# 7466     0.0                   NaN       NaN         NaN         NaN
# 7467     0.0                   NaN       NaN         NaN         NaN
# 7480     0.0                   NaN       NaN         NaN         NaN
# 7481     0.0                   NaN       NaN         NaN         NaN
# 7483     0.0                   NaN       NaN         NaN         NaN
# 7484     0.0                   NaN       NaN         NaN         NaN
# 7485     0.0                   NaN       NaN         NaN         NaN
#
#       CHO_Factor  score
# 7317         NaN     17
# 7462         NaN     25
# 7463         NaN     28
# 7464         NaN     36
# 7465         NaN     20
# 7466         NaN     30
# 7467         NaN     22
# 7480         NaN     29
# 7481         NaN     48
# 7483         NaN     42
# 7484         NaN     29
# 7485         NaN     26
